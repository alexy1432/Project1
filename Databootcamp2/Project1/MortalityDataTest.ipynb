# %%
import pandas as pd

# %%
file = "Mortality_Data.csv"
df = pd.read_csv(file)
df.head()
# Out:
#          Location     State    FIPS  Mortality Rate 1980  Min Rate 1980  \
# 0   United States       NaN     NaN               507.37         499.60
# 1         Alabama       NaN     1.0               516.87         508.36
# 2  Autauga County   Alabama  1001.0               552.68         521.37
# 3  Baldwin County   Alabama  1003.0               445.67         423.09
# 4  Barbour County   Alabama  1005.0               515.53         484.52
#
#    Max Rate 1980  Mortality Rate 1985  Min Rate 1985  Max Rate 1985  \
# 0         514.90               468.10         460.74         475.17
# 1         524.93               485.17         477.42         493.18
# 2         586.71               523.12         492.13         551.59
# 3         467.49               419.28         400.00         438.89
# 4         547.21               468.71         443.66         493.54
#
#    Mortality Rate 1990  ...  Max Rate 2005  Mortality Rate 2010  \
# ...
